# %%
from time import time
import pandas as pd
import numpy as np
from PIL import Image
from keras import optimizers
import keras.layers.advanced_activations
import scipy
import random
import matplotlib.pyplot as plt  
from scipy.stats import norm  
import keras
from keras.models import Sequential
from keras.initializers import VarianceScaling,RandomNormal
from keras.layers import Input, Dense, Dropout, Conv2D, MaxPooling2D, concatenate
from keras.layers import UpSampling2D, Reshape, Lambda, Flatten, Activation,Concatenate
from keras.models import Model  
from keras.optimizers import SGD, Adadelta, Adagrad,Adam
from keras import backend as K  
from keras import objectives  
from keras.utils.vis_utils import plot_model  
from keras.utils import np_utils, generic_utils
import sys 
import tensorflow as tf
from keras.callbacks import TensorBoard, ModelCheckpoint
from keras.layers import BatchNormalization
from keras.layers.normalization import BatchNormalization
import matplotlib.pyplot as plt
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2,3'
import sklearn
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import NullFormatter
# %matplotlib inline
from sklearn import manifold, datasets,cluster
from sklearn.utils import check_random_state
from sklearn import metrics
# Out:
# /home/hsun/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train_img = np.load("img_set_clip.npy").reshape([-1,256,256,1])
train_seg = np.load("seg_set_clip.npy").reshape([-1,256,256,1])
train_flo = np.load("flo_set_rgb_clip.npy")
train_rflo = np.load("rflo_set_rgb_clip.npy")
#train_img = np.log(train_img+1.0)
train_img = train_img/train_img.max()
train_seg = np_utils.to_categorical(train_seg, 2)

# %% [markdown]
# # last lyr

# %%
img_rows, img_cols = 256, 256
img_channels = 1

batch_size =50
latent_dim = 256
nb_epoch = 50
intermediate_dim =256
original_dim = img_rows*img_cols
LRelu = 'relu'

#USE = 'autoencoder'
#USE = 'vae'
#encoder:

input_img = Input(shape=(img_rows, img_cols,img_channels))
input_flo = Input(shape=(img_rows, img_cols,3))
input_rflo = Input(shape=(img_rows, img_cols,3))

conv_1 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(input_img)
conv_1 = Activation('relu')(conv_1)
conv_1 = BatchNormalization()(conv_1)
maxpool_1 = MaxPooling2D((2, 2),padding='same')(conv_1)
#maxpool_1 = Dropout(0.3)(maxpool_1)


conv_2 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(maxpool_1)
conv_2 = Activation('relu')(conv_2)
#conv_2 = Dropout(0.3)(conv_2)
conv_2 = BatchNormalization()(conv_2)
maxpool_2 = MaxPooling2D((2, 2),  padding='same')(conv_2)
#maxpool_2 = Dropout(0.3)(maxpool_2)

conv_3 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_2)
conv_3 = Activation(LRelu)(conv_3)
#conv_3 = Dropout(0.3)(conv_3)
conv_3 = BatchNormalization()(conv_3)
maxpool_3 = MaxPooling2D((2, 2),  padding='same')(conv_3)
#maxpool_3 = Dropout(0.3)(maxpool_3)

conv_4 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_3)
conv_4 = Activation(LRelu)(conv_4)
#conv_4 = Dropout(0.3)(conv_4)
conv_4 = BatchNormalization()(conv_4)
maxpool_4 = MaxPooling2D((2, 2),  padding='same')(conv_4)
#maxpool_4 = Dropout(0.3)(maxpool_4)

#conv_5 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(maxpool_4)
#maxpool_5 = MaxPooling2D((2, 2),  padding='same')(conv_5)


#x = Conv2D(5, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
#x = MaxPooling2D((2, 2),  padding='same')(x)

visual = Flatten()(maxpool_4)
h_1 = Dense(intermediate_dim, activation='relu')(visual)#relu?
encoded = Dense(latent_dim, activation='tanh')(h_1)# relu?


h_3 = Dense(intermediate_dim,activation=LRelu)(encoded)#for AE

h_4 = Dense(20*16*16,activation=LRelu)(h_3)
h_5 = Reshape((16,16,20))(h_4)


#conv_6 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
#upsample_6 = UpSampling2D((2, 2))(conv_6)

conv_7 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
upsample_7 = UpSampling2D((2, 2))(conv_7)

upsample_7 = Concatenate()([upsample_7,conv_4])
conv_8 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(upsample_7)
upsample_8 = UpSampling2D((2, 2))(conv_8)

upsample_8 = Concatenate()([upsample_8,conv_3])
conv_9 = Conv2D(10, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(upsample_8)
upsample_9 = UpSampling2D((2, 2))(conv_9)

upsample_9 = Concatenate()([upsample_9,conv_2])
conv_10 = Conv2D(5,  (3, 3), activation='relu',padding='same',kernel_initializer='normal')(upsample_9)
upsample_10 = UpSampling2D((2, 2))(conv_10)

upsample_10 = Concatenate()([upsample_10,conv_1,input_flo,input_rflo])
decoded = Conv2D(2, (3, 3), activation='softmax', padding='same')(upsample_10)
#decoded = Flatten()(decoded)
#decoded = Dense(256*256,activation='softmax')(decoded)


EarlyStopping = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=0, mode='auto')
checkpoint = ModelCheckpoint('model_keras0516GPU0.h5',monitor ='val_loss',verbose = 1,save_best_only = True)

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true[:,:,:,1]) 
    y_pred_f = K.flatten(y_pred[:,:,:,1]) 
    intersection = K.sum(y_true_f * y_pred_f) 
    return (2. * intersection + 1e-6) / (K.sum(K.square(y_true_f)) + K.sum(K.square(y_pred_f)) + 1e-6)
def dice_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

#def ae_loss(x, decoded):  
#    xent_loss = original_dim * objectives.mean_squared_error(x,decoded)
#    return xent_loss
adam = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
autoencoder = Model(inputs=[input_img,input_flo,input_rflo], outputs=decoded)
autoencoder.compile(optimizer=adam, loss=dice_loss)

# %%
#CheckPoint = keras.callbacks.ModelCheckpoint("Model_keras.h5", monitor='val_loss', verbose=0, save_best_only=False, save_weights_only=False, mode='auto', period=1)
autoencoder.fit([train_img[:1150],train_flo[:1150],train_rflo[:1150]], train_seg[:1150],
        shuffle=True,
        epochs=200,
        batch_size=batch_size,
        validation_data=([train_img[1150:],train_flo[1150:],train_rflo[1150:]],train_seg[1150:]),callbacks=[EarlyStopping,checkpoint])
# Out:
# Train on 1150 samples, validate on 127 samples
# Epoch 1/200
# 1150/1150 [==============================] - 11s 9ms/step - loss: -0.2392 - val_loss: -0.1064
#
# Epoch 00001: val_loss improved from inf to -0.10636, saving model to model_keras0516GPU0.h5
# Epoch 2/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.2788 - val_loss: -0.1792
#
# Epoch 00002: val_loss improved from -0.10636 to -0.17921, saving model to model_keras0516GPU0.h5
# Epoch 3/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.3903 - val_loss: -0.3314
#
# Epoch 00003: val_loss improved from -0.17921 to -0.33142, saving model to model_keras0516GPU0.h5
# Epoch 4/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.5137 - val_loss: -0.4147
#
# Epoch 00004: val_loss improved from -0.33142 to -0.41471, saving model to model_keras0516GPU0.h5
# Epoch 5/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.6019 - val_loss: -0.5121
#
# Epoch 00005: val_loss improved from -0.41471 to -0.51211, saving model to model_keras0516GPU0.h5
# Epoch 6/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.6816 - val_loss: -0.6347
#
# Epoch 00006: val_loss improved from -0.51211 to -0.63471, saving model to model_keras0516GPU0.h5
# Epoch 7/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.7683 - val_loss: -0.6673
#
# Epoch 00007: val_loss improved from -0.63471 to -0.66730, saving model to model_keras0516GPU0.h5
# Epoch 8/200
# 1150/1150 [==============================] - 8s 7ms/step - loss: -0.8287 - val_loss: -0.6798
#
# Epoch 00008: val_loss improved from -0.66730 to -0.67981, saving model to model_keras0516GPU0.h5
# Epoch 9/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.8654 - val_loss: -0.7351
#
# Epoch 00009: val_loss improved from -0.67981 to -0.73508, saving model to model_keras0516GPU0.h5
# Epoch 10/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.8872 - val_loss: -0.7634
#
# Epoch 00010: val_loss improved from -0.73508 to -0.76343, saving model to model_keras0516GPU0.h5
# Epoch 11/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9028 - val_loss: -0.7132
#
# Epoch 00011: val_loss did not improve from -0.76343
# Epoch 12/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9137 - val_loss: -0.7728
#
# Epoch 00012: val_loss improved from -0.76343 to -0.77281, saving model to model_keras0516GPU0.h5
# Epoch 13/200
# 1150/1150 [==============================] - 8s 7ms/step - loss: -0.9212 - val_loss: -0.7656
#
# Epoch 00013: val_loss did not improve from -0.77281
# Epoch 14/200
# 1150/1150 [==============================] - 8s 7ms/step - loss: -0.9272 - val_loss: -0.7478
#
# Epoch 00014: val_loss did not improve from -0.77281
# Epoch 15/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9336 - val_loss: -0.7327
#
# Epoch 00015: val_loss did not improve from -0.77281
# Epoch 16/200
# 1150/1150 [==============================] - 8s 7ms/step - loss: -0.9369 - val_loss: -0.7434
#
# Epoch 00016: val_loss did not improve from -0.77281
# Epoch 17/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9401 - val_loss: -0.7555
#
# Epoch 00017: val_loss did not improve from -0.77281
# Epoch 18/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9417 - val_loss: -0.7632
#
# Epoch 00018: val_loss did not improve from -0.77281
# Epoch 19/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9431 - val_loss: -0.7724
#
# Epoch 00019: val_loss did not improve from -0.77281
# Epoch 20/200
# 1150/1150 [==============================] - 8s 7ms/step - loss: -0.9462 - val_loss: -0.7706
#
# Epoch 00020: val_loss did not improve from -0.77281
# Epoch 21/200
# 1150/1150 [==============================] - 8s 7ms/step - loss: -0.9489 - val_loss: -0.7686
#
# Epoch 00021: val_loss did not improve from -0.77281
# Epoch 22/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9509 - val_loss: -0.7570
#
# Epoch 00022: val_loss did not improve from -0.77281
# Epoch 23/200
# 1150/1150 [==============================] - 8s 7ms/step - loss: -0.9532 - val_loss: -0.7629
#
# Epoch 00023: val_loss did not improve from -0.77281
# Epoch 24/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9560 - val_loss: -0.7766
#
# Epoch 00024: val_loss improved from -0.77281 to -0.77663, saving model to model_keras0516GPU0.h5
# Epoch 25/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9562 - val_loss: -0.7746
#
# Epoch 00025: val_loss did not improve from -0.77663
# Epoch 26/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9585 - val_loss: -0.7673
#
# Epoch 00026: val_loss did not improve from -0.77663
# Epoch 27/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9589 - val_loss: -0.7296
#
# Epoch 00027: val_loss did not improve from -0.77663
# Epoch 28/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9601 - val_loss: -0.7655
#
# Epoch 00028: val_loss did not improve from -0.77663
# Epoch 29/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9612 - val_loss: -0.7672
#
# Epoch 00029: val_loss did not improve from -0.77663
# Epoch 30/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9624 - val_loss: -0.7645
#
# Epoch 00030: val_loss did not improve from -0.77663
# Epoch 31/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9638 - val_loss: -0.7664
#
# Epoch 00031: val_loss did not improve from -0.77663
# Epoch 32/200
# 1150/1150 [==============================] - 8s 7ms/step - loss: -0.9638 - val_loss: -0.7562
#
# Epoch 00032: val_loss did not improve from -0.77663
# Epoch 33/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9644 - val_loss: -0.7588
#
# Epoch 00033: val_loss did not improve from -0.77663
# Epoch 34/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9650 - val_loss: -0.7602
#
# Epoch 00034: val_loss did not improve from -0.77663
# Epoch 35/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9661 - val_loss: -0.7686
#
# Epoch 00035: val_loss did not improve from -0.77663
# Epoch 36/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9668 - val_loss: -0.7451
#
# Epoch 00036: val_loss did not improve from -0.77663
# Epoch 37/200
# 1150/1150 [==============================] - 7s 7ms/step - loss: -0.9659 - val_loss: -0.7106
#
# Epoch 00037: val_loss did not improve from -0.77663
# Epoch 38/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9653 - val_loss: -0.7623
#
# Epoch 00038: val_loss did not improve from -0.77663
# Epoch 39/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9669 - val_loss: -0.7208
#
# Epoch 00039: val_loss did not improve from -0.77663
# Epoch 40/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9671 - val_loss: -0.7526
#
# Epoch 00040: val_loss did not improve from -0.77663
# Epoch 41/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9684 - val_loss: -0.7689
#
# Epoch 00041: val_loss did not improve from -0.77663
# Epoch 42/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9697 - val_loss: -0.7461
#
# Epoch 00042: val_loss did not improve from -0.77663
# Epoch 43/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9704 - val_loss: -0.7563
#
# Epoch 00043: val_loss did not improve from -0.77663
# Epoch 44/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9703 - val_loss: -0.7601
#
# Epoch 00044: val_loss did not improve from -0.77663

# %% [markdown]
# # mid lyr

# %%
img_rows, img_cols = 256, 256
img_channels = 1

batch_size =50
latent_dim = 256
nb_epoch = 50
intermediate_dim =256
original_dim = img_rows*img_cols
LRelu = 'relu'

#USE = 'autoencoder'
#USE = 'vae'
#encoder:

input_img = Input(shape=(img_rows, img_cols,img_channels))
input_flo = Input(shape=(img_rows, img_cols,3))
input_rflo = Input(shape=(img_rows, img_cols,3))

concate_flo = Concatenate()([input_flo,input_rflo])
conv_flo_1 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(concate_flo)
conv_flo_1 = Activation('relu')(conv_flo_1)
conv_flo_1 = BatchNormalization()(conv_flo_1)
maxpool_flo_1 = MaxPooling2D((2, 2),padding='same')(conv_flo_1)
conv_flo_2 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(maxpool_flo_1)
conv_flo_2 = Activation('relu')(conv_flo_2)
conv_flo_2 = BatchNormalization()(conv_flo_2)
maxpool_flo_2 = MaxPooling2D((2, 2),  padding='same')(conv_flo_2)
conv_flo_3 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_flo_2)
conv_flo_3 = Activation(LRelu)(conv_flo_3)
conv_flo_3 = BatchNormalization()(conv_flo_3)
maxpool_flo_3 = MaxPooling2D((2, 2),  padding='same')(conv_flo_3)
conv_flo_4 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_flo_3)
conv_flo_4 = Activation(LRelu)(conv_flo_4)
conv_flo_4 = BatchNormalization()(conv_flo_4)
maxpool_flo_4 = MaxPooling2D((2, 2),  padding='same')(conv_flo_4)






conv_1 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(input_img)
conv_1 = Activation('relu')(conv_1)
conv_1 = BatchNormalization()(conv_1)
maxpool_1 = MaxPooling2D((2, 2),padding='same')(conv_1)
#maxpool_1 = Dropout(0.3)(maxpool_1)

conv_2 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(maxpool_1)
conv_2 = Activation('relu')(conv_2)
#conv_2 = Dropout(0.3)(conv_2)
conv_2 = BatchNormalization()(conv_2)
maxpool_2 = MaxPooling2D((2, 2),  padding='same')(conv_2)
#maxpool_2 = Dropout(0.3)(maxpool_2)

conv_3 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_2)
conv_3 = Activation(LRelu)(conv_3)
#conv_3 = Dropout(0.3)(conv_3)
conv_3 = BatchNormalization()(conv_3)
maxpool_3 = MaxPooling2D((2, 2),  padding='same')(conv_3)
#maxpool_3 = Dropout(0.3)(maxpool_3)

conv_4 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_3)
conv_4 = Activation(LRelu)(conv_4)
#conv_4 = Dropout(0.3)(conv_4)
conv_4 = BatchNormalization()(conv_4)
maxpool_4 = MaxPooling2D((2, 2),  padding='same')(conv_4)
#maxpool_4 = Dropout(0.3)(maxpool_4)

#conv_5 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(maxpool_4)
#maxpool_5 = MaxPooling2D((2, 2),  padding='same')(conv_5)


#x = Conv2D(5, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
#x = MaxPooling2D((2, 2),  padding='same')(x)

maxpool_4 = Concatenate()([maxpool_flo_4,maxpool_4])
visual = Flatten()(maxpool_4)
h_1 = Dense(intermediate_dim, activation='relu')(visual)#relu?
encoded = Dense(latent_dim, activation='tanh')(h_1)# relu?


h_3 = Dense(intermediate_dim,activation=LRelu)(encoded)#for AE

h_4 = Dense(20*16*16,activation=LRelu)(h_3)
h_5 = Reshape((16,16,20))(h_4)


#conv_6 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
#upsample_6 = UpSampling2D((2, 2))(conv_6)

conv_7 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
upsample_7 = UpSampling2D((2, 2))(conv_7)

upsample_7 = Concatenate()([upsample_7,conv_4])
conv_8 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(upsample_7)
upsample_8 = UpSampling2D((2, 2))(conv_8)

upsample_8 = Concatenate()([upsample_8,conv_3])
conv_9 = Conv2D(10, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(upsample_8)
upsample_9 = UpSampling2D((2, 2))(conv_9)

upsample_9 = Concatenate()([upsample_9,conv_2])
conv_10 = Conv2D(5,  (3, 3), activation='relu',padding='same',kernel_initializer='normal')(upsample_9)
upsample_10 = UpSampling2D((2, 2))(conv_10)

upsample_10 = Concatenate()([upsample_10,conv_1])
decoded = Conv2D(2, (3, 3), activation='softmax', padding='same')(upsample_10)
#decoded = Flatten()(decoded)
#decoded = Dense(256*256,activation='softmax')(decoded)


EarlyStopping = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=0, mode='auto')
checkpoint = ModelCheckpoint('model_keras0516GPU0.h5',monitor ='val_loss',verbose = 1,save_best_only = True)

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true[:,:,:,1]) 
    y_pred_f = K.flatten(y_pred[:,:,:,1]) 
    intersection = K.sum(y_true_f * y_pred_f) 
    return (2. * intersection + 1e-6) / (K.sum(K.square(y_true_f)) + K.sum(K.square(y_pred_f)) + 1e-6)
def dice_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

#def ae_loss(x, decoded):  
#    xent_loss = original_dim * objectives.mean_squared_error(x,decoded)
#    return xent_loss
adam = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
autoencoder = Model(inputs=[input_img,input_flo,input_rflo], outputs=decoded)
autoencoder.compile(optimizer=adam, loss=dice_loss)

# %%
#CheckPoint = keras.callbacks.ModelCheckpoint("Model_keras.h5", monitor='val_loss', verbose=0, save_best_only=False, save_weights_only=False, mode='auto', period=1)
autoencoder.fit([train_img[:1150],train_flo[:1150],train_rflo[:1150]], train_seg[:1150],
        shuffle=True,
        epochs=200,
        batch_size=batch_size,
        validation_data=([train_img[1150:],train_flo[1150:],train_rflo[1150:]],train_seg[1150:]),callbacks=[EarlyStopping,checkpoint])
# Out:
# Train on 1150 samples, validate on 127 samples
# Epoch 1/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.2028 - val_loss: -0.0808
#
# Epoch 00001: val_loss improved from inf to -0.08077, saving model to model_keras0516GPU0.h5
# Epoch 2/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.2293 - val_loss: -0.0926
#
# Epoch 00002: val_loss improved from -0.08077 to -0.09257, saving model to model_keras0516GPU0.h5
# Epoch 3/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.2921 - val_loss: -0.1751
#
# Epoch 00003: val_loss improved from -0.09257 to -0.17506, saving model to model_keras0516GPU0.h5
# Epoch 4/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.4863 - val_loss: -0.3692
#
# Epoch 00004: val_loss improved from -0.17506 to -0.36918, saving model to model_keras0516GPU0.h5
# Epoch 5/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.6204 - val_loss: -0.5459
#
# Epoch 00005: val_loss improved from -0.36918 to -0.54587, saving model to model_keras0516GPU0.h5
# Epoch 6/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.7374 - val_loss: -0.5502
#
# Epoch 00006: val_loss improved from -0.54587 to -0.55021, saving model to model_keras0516GPU0.h5
# Epoch 7/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.8189 - val_loss: -0.6607
#
# Epoch 00007: val_loss improved from -0.55021 to -0.66069, saving model to model_keras0516GPU0.h5
# Epoch 8/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.8579 - val_loss: -0.6398
#
# Epoch 00008: val_loss did not improve from -0.66069
# Epoch 9/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.8845 - val_loss: -0.6885
#
# Epoch 00009: val_loss improved from -0.66069 to -0.68854, saving model to model_keras0516GPU0.h5
# Epoch 10/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9022 - val_loss: -0.7179
#
# Epoch 00010: val_loss improved from -0.68854 to -0.71793, saving model to model_keras0516GPU0.h5
# Epoch 11/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9123 - val_loss: -0.7467
#
# Epoch 00011: val_loss improved from -0.71793 to -0.74671, saving model to model_keras0516GPU0.h5
# Epoch 12/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9229 - val_loss: -0.7510
#
# Epoch 00012: val_loss improved from -0.74671 to -0.75097, saving model to model_keras0516GPU0.h5
# Epoch 13/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9295 - val_loss: -0.7588
#
# Epoch 00013: val_loss improved from -0.75097 to -0.75878, saving model to model_keras0516GPU0.h5
# Epoch 14/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9355 - val_loss: -0.7685
#
# Epoch 00014: val_loss improved from -0.75878 to -0.76847, saving model to model_keras0516GPU0.h5
# Epoch 15/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9382 - val_loss: -0.7699
#
# Epoch 00015: val_loss improved from -0.76847 to -0.76993, saving model to model_keras0516GPU0.h5
# Epoch 16/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9394 - val_loss: -0.7604
#
# Epoch 00016: val_loss did not improve from -0.76993
# Epoch 17/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9432 - val_loss: -0.7049
#
# Epoch 00017: val_loss did not improve from -0.76993
# Epoch 18/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9460 - val_loss: -0.7655
#
# Epoch 00018: val_loss did not improve from -0.76993
# Epoch 19/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9499 - val_loss: -0.7632
#
# Epoch 00019: val_loss did not improve from -0.76993
# Epoch 20/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9526 - val_loss: -0.7603
#
# Epoch 00020: val_loss did not improve from -0.76993
# Epoch 21/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9548 - val_loss: -0.7711
#
# Epoch 00021: val_loss improved from -0.76993 to -0.77111, saving model to model_keras0516GPU0.h5
# Epoch 22/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9568 - val_loss: -0.7673
#
# Epoch 00022: val_loss did not improve from -0.77111
# Epoch 23/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9572 - val_loss: -0.7384
#
# Epoch 00023: val_loss did not improve from -0.77111
# Epoch 24/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9597 - val_loss: -0.7630
#
# Epoch 00024: val_loss did not improve from -0.77111
# Epoch 25/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9599 - val_loss: -0.7602
#
# Epoch 00025: val_loss did not improve from -0.77111
# Epoch 26/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9621 - val_loss: -0.7497
#
# Epoch 00026: val_loss did not improve from -0.77111
# Epoch 27/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9630 - val_loss: -0.7388
#
# Epoch 00027: val_loss did not improve from -0.77111
# Epoch 28/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9639 - val_loss: -0.7516
#
# Epoch 00028: val_loss did not improve from -0.77111
# Epoch 29/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9654 - val_loss: -0.7441
#
# Epoch 00029: val_loss did not improve from -0.77111
# Epoch 30/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9651 - val_loss: -0.7274
#
# Epoch 00030: val_loss did not improve from -0.77111
# Epoch 31/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9645 - val_loss: -0.7670
#
# Epoch 00031: val_loss did not improve from -0.77111
# Epoch 32/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9674 - val_loss: -0.7336
#
# Epoch 00032: val_loss did not improve from -0.77111
# Epoch 33/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9676 - val_loss: -0.7654
#
# Epoch 00033: val_loss did not improve from -0.77111
# Epoch 34/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9676 - val_loss: -0.7588
#
# Epoch 00034: val_loss did not improve from -0.77111
# Epoch 35/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9685 - val_loss: -0.7314
#
# Epoch 00035: val_loss did not improve from -0.77111
# Epoch 36/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9698 - val_loss: -0.7415
#
# Epoch 00036: val_loss did not improve from -0.77111
# Epoch 37/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9707 - val_loss: -0.7509
#
# Epoch 00037: val_loss did not improve from -0.77111
# Epoch 38/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9712 - val_loss: -0.7548
#
# Epoch 00038: val_loss did not improve from -0.77111
# Epoch 39/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9718 - val_loss: -0.7557
#
# Epoch 00039: val_loss did not improve from -0.77111
# Epoch 40/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9728 - val_loss: -0.7546
#
# Epoch 00040: val_loss did not improve from -0.77111
# Epoch 41/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9733 - val_loss: -0.7425
#
# Epoch 00041: val_loss did not improve from -0.77111

# %% [markdown]
# # conv to last lyr

# %%
img_rows, img_cols = 256, 256
img_channels = 1

batch_size =50
latent_dim = 256
nb_epoch = 50
intermediate_dim =256
original_dim = img_rows*img_cols
LRelu = 'relu'

#USE = 'autoencoder'
#USE = 'vae'
#encoder:

input_img = Input(shape=(img_rows, img_cols,img_channels))
input_flo = Input(shape=(img_rows, img_cols,3))
input_rflo = Input(shape=(img_rows, img_cols,3))

concate_flo = Concatenate()([input_flo,input_rflo])
conv_flo_1 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(concate_flo)
conv_flo_1 = Activation('relu')(conv_flo_1)
conv_flo_1 = BatchNormalization()(conv_flo_1)
#maxpool_flo_1 = MaxPooling2D((2, 2),padding='same')(conv_flo_1)
conv_flo_2 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(conv_flo_1)
conv_flo_2 = Activation('relu')(conv_flo_2)
conv_flo_2 = BatchNormalization()(conv_flo_2)
#maxpool_flo_2 = MaxPooling2D((2, 2),  padding='same')(conv_flo_2)
conv_flo_3 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(conv_flo_2)
conv_flo_3 = Activation(LRelu)(conv_flo_3)
conv_flo_3 = BatchNormalization()(conv_flo_3)






conv_1 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(input_img)
conv_1 = Activation('relu')(conv_1)
conv_1 = BatchNormalization()(conv_1)
maxpool_1 = MaxPooling2D((2, 2),padding='same')(conv_1)
#maxpool_1 = Dropout(0.3)(maxpool_1)

conv_2 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(maxpool_1)
conv_2 = Activation('relu')(conv_2)
#conv_2 = Dropout(0.3)(conv_2)
conv_2 = BatchNormalization()(conv_2)
maxpool_2 = MaxPooling2D((2, 2),  padding='same')(conv_2)
#maxpool_2 = Dropout(0.3)(maxpool_2)

conv_3 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_2)
conv_3 = Activation(LRelu)(conv_3)
#conv_3 = Dropout(0.3)(conv_3)
conv_3 = BatchNormalization()(conv_3)
maxpool_3 = MaxPooling2D((2, 2),  padding='same')(conv_3)
#maxpool_3 = Dropout(0.3)(maxpool_3)

conv_4 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_3)
conv_4 = Activation(LRelu)(conv_4)
#conv_4 = Dropout(0.3)(conv_4)
conv_4 = BatchNormalization()(conv_4)
maxpool_4 = MaxPooling2D((2, 2),  padding='same')(conv_4)
#maxpool_4 = Dropout(0.3)(maxpool_4)

#conv_5 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(maxpool_4)
#maxpool_5 = MaxPooling2D((2, 2),  padding='same')(conv_5)


#x = Conv2D(5, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
#x = MaxPooling2D((2, 2),  padding='same')(x)


visual = Flatten()(maxpool_4)
h_1 = Dense(intermediate_dim, activation='relu')(visual)#relu?
encoded = Dense(latent_dim, activation='tanh')(h_1)# relu?


h_3 = Dense(intermediate_dim,activation=LRelu)(encoded)#for AE

h_4 = Dense(20*16*16,activation=LRelu)(h_3)
h_5 = Reshape((16,16,20))(h_4)


#conv_6 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
#upsample_6 = UpSampling2D((2, 2))(conv_6)

conv_7 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
upsample_7 = UpSampling2D((2, 2))(conv_7)

upsample_7 = Concatenate()([upsample_7,conv_4])
conv_8 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(upsample_7)
upsample_8 = UpSampling2D((2, 2))(conv_8)

upsample_8 = Concatenate()([upsample_8,conv_3])
conv_9 = Conv2D(10, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(upsample_8)
upsample_9 = UpSampling2D((2, 2))(conv_9)

upsample_9 = Concatenate()([upsample_9,conv_2])
conv_10 = Conv2D(5,  (3, 3), activation='relu',padding='same',kernel_initializer='normal')(upsample_9)
upsample_10 = UpSampling2D((2, 2))(conv_10)

upsample_10 = Concatenate()([upsample_10,conv_1,conv_flo_3])
decoded = Conv2D(2, (3, 3), activation='softmax', padding='same')(upsample_10)
#decoded = Flatten()(decoded)
#decoded = Dense(256*256,activation='softmax')(decoded)


EarlyStopping = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=0, mode='auto')
checkpoint = ModelCheckpoint('model_keras0516GPU0.h5',monitor ='val_loss',verbose = 1,save_best_only = True)

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true[:,:,:,1]) 
    y_pred_f = K.flatten(y_pred[:,:,:,1]) 
    intersection = K.sum(y_true_f * y_pred_f) 
    return (2. * intersection + 1e-6) / (K.sum(K.square(y_true_f)) + K.sum(K.square(y_pred_f)) + 1e-6)
def dice_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

#def ae_loss(x, decoded):  
#    xent_loss = original_dim * objectives.mean_squared_error(x,decoded)
#    return xent_loss
adam = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
autoencoder = Model(inputs=[input_img,input_flo,input_rflo], outputs=decoded)
autoencoder.compile(optimizer=adam, loss=dice_loss)

# %%
#CheckPoint = keras.callbacks.ModelCheckpoint("Model_keras.h5", monitor='val_loss', verbose=0, save_best_only=False, save_weights_only=False, mode='auto', period=1)
autoencoder.fit([train_img[:1150],train_flo[:1150],train_rflo[:1150]], train_seg[:1150],
        shuffle=True,
        epochs=200,
        batch_size=batch_size,
        validation_data=([train_img[1150:],train_flo[1150:],train_rflo[1150:]],train_seg[1150:]),callbacks=[EarlyStopping,checkpoint])
# Out:
# Train on 1150 samples, validate on 127 samples
# Epoch 1/200
# 1150/1150 [==============================] - 16s 14ms/step - loss: -0.1802 - val_loss: -0.0501
#
# Epoch 00001: val_loss improved from inf to -0.05013, saving model to model_keras0516GPU0.h5
# Epoch 2/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.2084 - val_loss: -0.0609
#
# Epoch 00002: val_loss improved from -0.05013 to -0.06085, saving model to model_keras0516GPU0.h5
# Epoch 3/200
# 1150/1150 [==============================] - 13s 11ms/step - loss: -0.2442 - val_loss: -0.0972
#
# Epoch 00003: val_loss improved from -0.06085 to -0.09720, saving model to model_keras0516GPU0.h5
# Epoch 4/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.2814 - val_loss: -0.1118
#
# Epoch 00004: val_loss improved from -0.09720 to -0.11178, saving model to model_keras0516GPU0.h5
# Epoch 5/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.3247 - val_loss: -0.1306
#
# Epoch 00005: val_loss improved from -0.11178 to -0.13061, saving model to model_keras0516GPU0.h5
# Epoch 6/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.5267 - val_loss: -0.4500
#
# Epoch 00006: val_loss improved from -0.13061 to -0.45002, saving model to model_keras0516GPU0.h5
# Epoch 7/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.8089 - val_loss: -0.6723
#
# Epoch 00007: val_loss improved from -0.45002 to -0.67233, saving model to model_keras0516GPU0.h5
# Epoch 8/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.8561 - val_loss: -0.6698
#
# Epoch 00008: val_loss did not improve from -0.67233
# Epoch 9/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.8794 - val_loss: -0.6850
#
# Epoch 00009: val_loss improved from -0.67233 to -0.68497, saving model to model_keras0516GPU0.h5
# Epoch 10/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.8927 - val_loss: -0.6029
#
# Epoch 00010: val_loss did not improve from -0.68497
# Epoch 11/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9020 - val_loss: -0.7201
#
# Epoch 00011: val_loss improved from -0.68497 to -0.72013, saving model to model_keras0516GPU0.h5
# Epoch 12/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9102 - val_loss: -0.4283
#
# Epoch 00012: val_loss did not improve from -0.72013
# Epoch 13/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9168 - val_loss: -0.6759
#
# Epoch 00013: val_loss did not improve from -0.72013
# Epoch 14/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9239 - val_loss: -0.6315
#
# Epoch 00014: val_loss did not improve from -0.72013
# Epoch 15/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9291 - val_loss: -0.6252
#
# Epoch 00015: val_loss did not improve from -0.72013
# Epoch 16/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9307 - val_loss: -0.7245
#
# Epoch 00016: val_loss improved from -0.72013 to -0.72454, saving model to model_keras0516GPU0.h5
# Epoch 17/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9348 - val_loss: -0.6229
#
# Epoch 00017: val_loss did not improve from -0.72454
# Epoch 18/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9379 - val_loss: -0.7450
#
# Epoch 00018: val_loss improved from -0.72454 to -0.74500, saving model to model_keras0516GPU0.h5
# Epoch 19/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9412 - val_loss: -0.5940
#
# Epoch 00019: val_loss did not improve from -0.74500
# Epoch 20/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9436 - val_loss: -0.6849
#
# Epoch 00020: val_loss did not improve from -0.74500
# Epoch 21/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9450 - val_loss: -0.7224
#
# Epoch 00021: val_loss did not improve from -0.74500
# Epoch 22/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9464 - val_loss: -0.7217
#
# Epoch 00022: val_loss did not improve from -0.74500
# Epoch 23/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9490 - val_loss: -0.7358
#
# Epoch 00023: val_loss did not improve from -0.74500
# Epoch 24/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9480 - val_loss: -0.6874
#
# Epoch 00024: val_loss did not improve from -0.74500
# Epoch 25/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9495 - val_loss: -0.6885
#
# Epoch 00025: val_loss did not improve from -0.74500
# Epoch 26/200
# 1150/1150 [==============================] - 13s 11ms/step - loss: -0.9517 - val_loss: -0.7002
#
# Epoch 00026: val_loss did not improve from -0.74500
# Epoch 27/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9534 - val_loss: -0.6996
#
# Epoch 00027: val_loss did not improve from -0.74500
# Epoch 28/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9552 - val_loss: -0.6468
#
# Epoch 00028: val_loss did not improve from -0.74500
# Epoch 29/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9555 - val_loss: -0.7415
#
# Epoch 00029: val_loss did not improve from -0.74500
# Epoch 30/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9559 - val_loss: -0.6065
#
# Epoch 00030: val_loss did not improve from -0.74500
# Epoch 31/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9582 - val_loss: -0.7165
#
# Epoch 00031: val_loss did not improve from -0.74500
# Epoch 32/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9600 - val_loss: -0.6678
#
# Epoch 00032: val_loss did not improve from -0.74500
# Epoch 33/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9609 - val_loss: -0.7372
#
# Epoch 00033: val_loss did not improve from -0.74500
# Epoch 34/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9618 - val_loss: -0.7369
#
# Epoch 00034: val_loss did not improve from -0.74500
# Epoch 35/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9626 - val_loss: -0.7420
#
# Epoch 00035: val_loss did not improve from -0.74500
# Epoch 36/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9638 - val_loss: -0.7390
#
# Epoch 00036: val_loss did not improve from -0.74500
# Epoch 37/200
# 1150/1150 [==============================] - 13s 11ms/step - loss: -0.9639 - val_loss: -0.7069
#
# Epoch 00037: val_loss did not improve from -0.74500
# Epoch 38/200
# 1150/1150 [==============================] - 13s 11ms/step - loss: -0.9653 - val_loss: -0.7109
#
# Epoch 00038: val_loss did not improve from -0.74500
