# %%
from time import time
import pandas as pd
import numpy as np
from PIL import Image
from keras import optimizers
import keras.layers.advanced_activations
import scipy
import random
import matplotlib.pyplot as plt  
from scipy.stats import norm  
import keras
from keras.models import Sequential
from keras.initializers import VarianceScaling,RandomNormal
from keras.layers import Input, Dense, Dropout, Conv2D, MaxPooling2D, concatenate
from keras.layers import UpSampling2D, Reshape, Lambda, Flatten, Activation,Concatenate
from keras.models import Model  
from keras.optimizers import SGD, Adadelta, Adagrad,Adam
from keras import backend as K  
from keras import objectives  
from keras.utils.vis_utils import plot_model  
from keras.utils import np_utils, generic_utils
import sys 
import tensorflow as tf
from keras.callbacks import TensorBoard, ModelCheckpoint
from keras.layers import BatchNormalization
from keras.layers.normalization import BatchNormalization
import matplotlib.pyplot as plt
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1,6,7'
import sklearn
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import NullFormatter
# %matplotlib inline
from sklearn import manifold, datasets,cluster
from sklearn.utils import check_random_state
from sklearn import metrics

# %%
train_img = np.load("img_set_log.npy").reshape([-1,256,256,1])
train_seg = np.load("seg_set_log.npy").reshape([-1,256,256,1])
train_flo = np.load("flo_set_rgb_log.npy")
train_rflo = np.load("rflo_set_rgb_log.npy")
#train_img = np.log(train_img+1.0)
train_img = train_img/train_img.max()
train_seg = np_utils.to_categorical(train_seg, 2)

# %% [markdown]
# # last lyr

# %%
img_rows, img_cols = 256, 256
img_channels = 1

batch_size =50
latent_dim = 256
nb_epoch = 50
intermediate_dim =256
original_dim = img_rows*img_cols
LRelu = 'relu'

#USE = 'autoencoder'
#USE = 'vae'
#encoder:

input_img = Input(shape=(img_rows, img_cols,img_channels))
input_flo = Input(shape=(img_rows, img_cols,3))
input_rflo = Input(shape=(img_rows, img_cols,3))

conv_1 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(input_img)
conv_1 = Activation('relu')(conv_1)
conv_1 = BatchNormalization()(conv_1)
maxpool_1 = MaxPooling2D((2, 2),padding='same')(conv_1)
#maxpool_1 = Dropout(0.3)(maxpool_1)


conv_2 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(maxpool_1)
conv_2 = Activation('relu')(conv_2)
#conv_2 = Dropout(0.3)(conv_2)
conv_2 = BatchNormalization()(conv_2)
maxpool_2 = MaxPooling2D((2, 2),  padding='same')(conv_2)
#maxpool_2 = Dropout(0.3)(maxpool_2)

conv_3 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_2)
conv_3 = Activation(LRelu)(conv_3)
#conv_3 = Dropout(0.3)(conv_3)
conv_3 = BatchNormalization()(conv_3)
maxpool_3 = MaxPooling2D((2, 2),  padding='same')(conv_3)
#maxpool_3 = Dropout(0.3)(maxpool_3)

conv_4 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_3)
conv_4 = Activation(LRelu)(conv_4)
#conv_4 = Dropout(0.3)(conv_4)
conv_4 = BatchNormalization()(conv_4)
maxpool_4 = MaxPooling2D((2, 2),  padding='same')(conv_4)
#maxpool_4 = Dropout(0.3)(maxpool_4)

#conv_5 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(maxpool_4)
#maxpool_5 = MaxPooling2D((2, 2),  padding='same')(conv_5)


#x = Conv2D(5, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
#x = MaxPooling2D((2, 2),  padding='same')(x)

visual = Flatten()(maxpool_4)
h_1 = Dense(intermediate_dim, activation='relu')(visual)#relu?
encoded = Dense(latent_dim, activation='tanh')(h_1)# relu?


h_3 = Dense(intermediate_dim,activation=LRelu)(encoded)#for AE

h_4 = Dense(20*16*16,activation=LRelu)(h_3)
h_5 = Reshape((16,16,20))(h_4)


#conv_6 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
#upsample_6 = UpSampling2D((2, 2))(conv_6)

conv_7 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
upsample_7 = UpSampling2D((2, 2))(conv_7)

upsample_7 = Concatenate()([upsample_7,conv_4])
conv_8 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(upsample_7)
upsample_8 = UpSampling2D((2, 2))(conv_8)

upsample_8 = Concatenate()([upsample_8,conv_3])
conv_9 = Conv2D(10, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(upsample_8)
upsample_9 = UpSampling2D((2, 2))(conv_9)

upsample_9 = Concatenate()([upsample_9,conv_2])
conv_10 = Conv2D(5,  (3, 3), activation='relu',padding='same',kernel_initializer='normal')(upsample_9)
upsample_10 = UpSampling2D((2, 2))(conv_10)

upsample_10 = Concatenate()([upsample_10,conv_1,input_flo,input_rflo])
decoded = Conv2D(2, (3, 3), activation='softmax', padding='same')(upsample_10)
#decoded = Flatten()(decoded)
#decoded = Dense(256*256,activation='softmax')(decoded)


EarlyStopping = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=0, mode='auto')
checkpoint = ModelCheckpoint('model_keras0516GPU0.h5',monitor ='val_loss',verbose = 1,save_best_only = True)

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true[:,:,:,1]) 
    y_pred_f = K.flatten(y_pred[:,:,:,1]) 
    intersection = K.sum(y_true_f * y_pred_f) 
    return (2. * intersection + 1e-6) / (K.sum(K.square(y_true_f)) + K.sum(K.square(y_pred_f)) + 1e-6)
def dice_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

#def ae_loss(x, decoded):  
#    xent_loss = original_dim * objectives.mean_squared_error(x,decoded)
#    return xent_loss
adam = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
autoencoder = Model(inputs=[input_img,input_flo,input_rflo], outputs=decoded)
autoencoder.compile(optimizer=adam, loss=dice_loss)

# %%
#CheckPoint = keras.callbacks.ModelCheckpoint("Model_keras.h5", monitor='val_loss', verbose=0, save_best_only=False, save_weights_only=False, mode='auto', period=1)
autoencoder.fit([train_img[:1150],train_flo[:1150],train_rflo[:1150]], train_seg[:1150],
        shuffle=True,
        epochs=200,
        batch_size=batch_size,
        validation_data=([train_img[1150:],train_flo[1150:],train_rflo[1150:]],train_seg[1150:]),callbacks=[EarlyStopping,checkpoint])
# Out:
# Train on 1150 samples, validate on 127 samples
# Epoch 1/200
# 1150/1150 [==============================] - 10s 9ms/step - loss: -0.1729 - val_loss: -0.0528
#
# Epoch 00001: val_loss improved from inf to -0.05282, saving model to model_keras0516GPU0.h5
# Epoch 2/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.2104 - val_loss: -0.0615
#
# Epoch 00002: val_loss improved from -0.05282 to -0.06149, saving model to model_keras0516GPU0.h5
# Epoch 3/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.3177 - val_loss: -0.1941
#
# Epoch 00003: val_loss improved from -0.06149 to -0.19408, saving model to model_keras0516GPU0.h5
# Epoch 4/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.5329 - val_loss: -0.4248
#
# Epoch 00004: val_loss improved from -0.19408 to -0.42479, saving model to model_keras0516GPU0.h5
# Epoch 5/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.5996 - val_loss: -0.4864
#
# Epoch 00005: val_loss improved from -0.42479 to -0.48642, saving model to model_keras0516GPU0.h5
# Epoch 6/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.6673 - val_loss: -0.5775
#
# Epoch 00006: val_loss improved from -0.48642 to -0.57745, saving model to model_keras0516GPU0.h5
# Epoch 7/200
# 1150/1150 [==============================] - 8s 7ms/step - loss: -0.7403 - val_loss: -0.5967
#
# Epoch 00007: val_loss improved from -0.57745 to -0.59666, saving model to model_keras0516GPU0.h5
# Epoch 8/200
# 1150/1150 [==============================] - 7s 7ms/step - loss: -0.7967 - val_loss: -0.5776
#
# Epoch 00008: val_loss did not improve from -0.59666
# Epoch 9/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.8320 - val_loss: -0.7372
#
# Epoch 00009: val_loss improved from -0.59666 to -0.73723, saving model to model_keras0516GPU0.h5
# Epoch 10/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.8593 - val_loss: -0.7641
#
# Epoch 00010: val_loss improved from -0.73723 to -0.76410, saving model to model_keras0516GPU0.h5
# Epoch 11/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.8732 - val_loss: -0.7601
#
# Epoch 00011: val_loss did not improve from -0.76410
# Epoch 12/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.8862 - val_loss: -0.7524
#
# Epoch 00012: val_loss did not improve from -0.76410
# Epoch 13/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.8986 - val_loss: -0.7760
#
# Epoch 00013: val_loss improved from -0.76410 to -0.77597, saving model to model_keras0516GPU0.h5
# Epoch 14/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9097 - val_loss: -0.7541
#
# Epoch 00014: val_loss did not improve from -0.77597
# Epoch 15/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9172 - val_loss: -0.7605
#
# Epoch 00015: val_loss did not improve from -0.77597
# Epoch 16/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9213 - val_loss: -0.7684
#
# Epoch 00016: val_loss did not improve from -0.77597
# Epoch 17/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9256 - val_loss: -0.7565
#
# Epoch 00017: val_loss did not improve from -0.77597
# Epoch 18/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9319 - val_loss: -0.7528
#
# Epoch 00018: val_loss did not improve from -0.77597
# Epoch 19/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9328 - val_loss: -0.7581
#
# Epoch 00019: val_loss did not improve from -0.77597
# Epoch 20/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9352 - val_loss: -0.7486
#
# Epoch 00020: val_loss did not improve from -0.77597
# Epoch 21/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9386 - val_loss: -0.7531
#
# Epoch 00021: val_loss did not improve from -0.77597
# Epoch 22/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9413 - val_loss: -0.7752
#
# Epoch 00022: val_loss did not improve from -0.77597
# Epoch 23/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9434 - val_loss: -0.7347
#
# Epoch 00023: val_loss did not improve from -0.77597
# Epoch 24/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9465 - val_loss: -0.7628
#
# Epoch 00024: val_loss did not improve from -0.77597
# Epoch 25/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9490 - val_loss: -0.7615
#
# Epoch 00025: val_loss did not improve from -0.77597
# Epoch 26/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9493 - val_loss: -0.7588
#
# Epoch 00026: val_loss did not improve from -0.77597
# Epoch 27/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9513 - val_loss: -0.7319
#
# Epoch 00027: val_loss did not improve from -0.77597
# Epoch 28/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9538 - val_loss: -0.7543
#
# Epoch 00028: val_loss did not improve from -0.77597
# Epoch 29/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9544 - val_loss: -0.7391
#
# Epoch 00029: val_loss did not improve from -0.77597
# Epoch 30/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9556 - val_loss: -0.7553
#
# Epoch 00030: val_loss did not improve from -0.77597
# Epoch 31/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9573 - val_loss: -0.7532
#
# Epoch 00031: val_loss did not improve from -0.77597
# Epoch 32/200
# 1150/1150 [==============================] - 7s 6ms/step - loss: -0.9582 - val_loss: -0.7530
#
# Epoch 00032: val_loss did not improve from -0.77597
# Epoch 33/200
# 1150/1150 [==============================] - 6s 6ms/step - loss: -0.9587 - val_loss: -0.7520
#
# Epoch 00033: val_loss did not improve from -0.77597

# %% [markdown]
# # mid lyr

# %%
img_rows, img_cols = 256, 256
img_channels = 1

batch_size =50
latent_dim = 256
nb_epoch = 50
intermediate_dim =256
original_dim = img_rows*img_cols
LRelu = 'relu'

#USE = 'autoencoder'
#USE = 'vae'
#encoder:

input_img = Input(shape=(img_rows, img_cols,img_channels))
input_flo = Input(shape=(img_rows, img_cols,3))
input_rflo = Input(shape=(img_rows, img_cols,3))

concate_flo = Concatenate()([input_flo,input_rflo])
conv_flo_1 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(concate_flo)
conv_flo_1 = Activation('relu')(conv_flo_1)
conv_flo_1 = BatchNormalization()(conv_flo_1)
maxpool_flo_1 = MaxPooling2D((2, 2),padding='same')(conv_flo_1)
conv_flo_2 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(maxpool_flo_1)
conv_flo_2 = Activation('relu')(conv_flo_2)
conv_flo_2 = BatchNormalization()(conv_flo_2)
maxpool_flo_2 = MaxPooling2D((2, 2),  padding='same')(conv_flo_2)
conv_flo_3 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_flo_2)
conv_flo_3 = Activation(LRelu)(conv_flo_3)
conv_flo_3 = BatchNormalization()(conv_flo_3)
maxpool_flo_3 = MaxPooling2D((2, 2),  padding='same')(conv_flo_3)
conv_flo_4 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_flo_3)
conv_flo_4 = Activation(LRelu)(conv_flo_4)
conv_flo_4 = BatchNormalization()(conv_flo_4)
maxpool_flo_4 = MaxPooling2D((2, 2),  padding='same')(conv_flo_4)






conv_1 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(input_img)
conv_1 = Activation('relu')(conv_1)
conv_1 = BatchNormalization()(conv_1)
maxpool_1 = MaxPooling2D((2, 2),padding='same')(conv_1)
#maxpool_1 = Dropout(0.3)(maxpool_1)

conv_2 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(maxpool_1)
conv_2 = Activation('relu')(conv_2)
#conv_2 = Dropout(0.3)(conv_2)
conv_2 = BatchNormalization()(conv_2)
maxpool_2 = MaxPooling2D((2, 2),  padding='same')(conv_2)
#maxpool_2 = Dropout(0.3)(maxpool_2)

conv_3 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_2)
conv_3 = Activation(LRelu)(conv_3)
#conv_3 = Dropout(0.3)(conv_3)
conv_3 = BatchNormalization()(conv_3)
maxpool_3 = MaxPooling2D((2, 2),  padding='same')(conv_3)
#maxpool_3 = Dropout(0.3)(maxpool_3)

conv_4 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_3)
conv_4 = Activation(LRelu)(conv_4)
#conv_4 = Dropout(0.3)(conv_4)
conv_4 = BatchNormalization()(conv_4)
maxpool_4 = MaxPooling2D((2, 2),  padding='same')(conv_4)
#maxpool_4 = Dropout(0.3)(maxpool_4)

#conv_5 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(maxpool_4)
#maxpool_5 = MaxPooling2D((2, 2),  padding='same')(conv_5)


#x = Conv2D(5, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
#x = MaxPooling2D((2, 2),  padding='same')(x)

maxpool_4 = Concatenate()([maxpool_flo_4,maxpool_4])
visual = Flatten()(maxpool_4)
h_1 = Dense(intermediate_dim, activation='relu')(visual)#relu?
encoded = Dense(latent_dim, activation='tanh')(h_1)# relu?


h_3 = Dense(intermediate_dim,activation=LRelu)(encoded)#for AE

h_4 = Dense(20*16*16,activation=LRelu)(h_3)
h_5 = Reshape((16,16,20))(h_4)


#conv_6 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
#upsample_6 = UpSampling2D((2, 2))(conv_6)

conv_7 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
upsample_7 = UpSampling2D((2, 2))(conv_7)

upsample_7 = Concatenate()([upsample_7,conv_4])
conv_8 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(upsample_7)
upsample_8 = UpSampling2D((2, 2))(conv_8)

upsample_8 = Concatenate()([upsample_8,conv_3])
conv_9 = Conv2D(10, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(upsample_8)
upsample_9 = UpSampling2D((2, 2))(conv_9)

upsample_9 = Concatenate()([upsample_9,conv_2])
conv_10 = Conv2D(5,  (3, 3), activation='relu',padding='same',kernel_initializer='normal')(upsample_9)
upsample_10 = UpSampling2D((2, 2))(conv_10)

upsample_10 = Concatenate()([upsample_10,conv_1])
decoded = Conv2D(2, (3, 3), activation='softmax', padding='same')(upsample_10)
#decoded = Flatten()(decoded)
#decoded = Dense(256*256,activation='softmax')(decoded)


EarlyStopping = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=0, mode='auto')
checkpoint = ModelCheckpoint('model_keras0516GPU0.h5',monitor ='val_loss',verbose = 1,save_best_only = True)

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true[:,:,:,1]) 
    y_pred_f = K.flatten(y_pred[:,:,:,1]) 
    intersection = K.sum(y_true_f * y_pred_f) 
    return (2. * intersection + 1e-6) / (K.sum(K.square(y_true_f)) + K.sum(K.square(y_pred_f)) + 1e-6)
def dice_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

#def ae_loss(x, decoded):  
#    xent_loss = original_dim * objectives.mean_squared_error(x,decoded)
#    return xent_loss
adam = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
autoencoder = Model(inputs=[input_img,input_flo,input_rflo], outputs=decoded)
autoencoder.compile(optimizer=adam, loss=dice_loss)

# %%
#CheckPoint = keras.callbacks.ModelCheckpoint("Model_keras.h5", monitor='val_loss', verbose=0, save_best_only=False, save_weights_only=False, mode='auto', period=1)
autoencoder.fit([train_img[:1150],train_flo[:1150],train_rflo[:1150]], train_seg[:1150],
        shuffle=True,
        epochs=200,
        batch_size=batch_size,
        validation_data=([train_img[1150:],train_flo[1150:],train_rflo[1150:]],train_seg[1150:]),callbacks=[EarlyStopping,checkpoint])
# Out:
# Train on 1150 samples, validate on 127 samples
# Epoch 1/200
# 1150/1150 [==============================] - 13s 11ms/step - loss: -0.2218 - val_loss: -0.0964
#
# Epoch 00001: val_loss improved from inf to -0.09638, saving model to model_keras0516GPU0.h5
# Epoch 2/200
# 1150/1150 [==============================] - 10s 8ms/step - loss: -0.2595 - val_loss: -0.1291
#
# Epoch 00002: val_loss improved from -0.09638 to -0.12913, saving model to model_keras0516GPU0.h5
# Epoch 3/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.3649 - val_loss: -0.3354
#
# Epoch 00003: val_loss improved from -0.12913 to -0.33545, saving model to model_keras0516GPU0.h5
# Epoch 4/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.5262 - val_loss: -0.5032
#
# Epoch 00004: val_loss improved from -0.33545 to -0.50320, saving model to model_keras0516GPU0.h5
# Epoch 5/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.6160 - val_loss: -0.5340
#
# Epoch 00005: val_loss improved from -0.50320 to -0.53401, saving model to model_keras0516GPU0.h5
# Epoch 6/200
# 1150/1150 [==============================] - 8s 7ms/step - loss: -0.6926 - val_loss: -0.4664
#
# Epoch 00006: val_loss did not improve from -0.53401
# Epoch 7/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.7856 - val_loss: -0.4373
#
# Epoch 00007: val_loss did not improve from -0.53401
# Epoch 8/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.8369 - val_loss: -0.2905
#
# Epoch 00008: val_loss did not improve from -0.53401
# Epoch 9/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.8676 - val_loss: -0.6354
#
# Epoch 00009: val_loss improved from -0.53401 to -0.63535, saving model to model_keras0516GPU0.h5
# Epoch 10/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.8915 - val_loss: -0.6500
#
# Epoch 00010: val_loss improved from -0.63535 to -0.64996, saving model to model_keras0516GPU0.h5
# Epoch 11/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9074 - val_loss: -0.7050
#
# Epoch 00011: val_loss improved from -0.64996 to -0.70496, saving model to model_keras0516GPU0.h5
# Epoch 12/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9181 - val_loss: -0.6941
#
# Epoch 00012: val_loss did not improve from -0.70496
# Epoch 13/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9257 - val_loss: -0.7123
#
# Epoch 00013: val_loss improved from -0.70496 to -0.71226, saving model to model_keras0516GPU0.h5
# Epoch 14/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9313 - val_loss: -0.7076
#
# Epoch 00014: val_loss did not improve from -0.71226
# Epoch 15/200
# 1150/1150 [==============================] - 8s 7ms/step - loss: -0.9318 - val_loss: -0.6695
#
# Epoch 00015: val_loss did not improve from -0.71226
# Epoch 16/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9359 - val_loss: -0.7374
#
# Epoch 00016: val_loss improved from -0.71226 to -0.73741, saving model to model_keras0516GPU0.h5
# Epoch 17/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9404 - val_loss: -0.7174
#
# Epoch 00017: val_loss did not improve from -0.73741
# Epoch 18/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9445 - val_loss: -0.7122
#
# Epoch 00018: val_loss did not improve from -0.73741
# Epoch 19/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9464 - val_loss: -0.7348
#
# Epoch 00019: val_loss did not improve from -0.73741
# Epoch 20/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9489 - val_loss: -0.7247
#
# Epoch 00020: val_loss did not improve from -0.73741
# Epoch 21/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9502 - val_loss: -0.7352
#
# Epoch 00021: val_loss did not improve from -0.73741
# Epoch 22/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9520 - val_loss: -0.7354
#
# Epoch 00022: val_loss did not improve from -0.73741
# Epoch 23/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9536 - val_loss: -0.7326
#
# Epoch 00023: val_loss did not improve from -0.73741
# Epoch 24/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9542 - val_loss: -0.7203
#
# Epoch 00024: val_loss did not improve from -0.73741
# Epoch 25/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9559 - val_loss: -0.7263
#
# Epoch 00025: val_loss did not improve from -0.73741
# Epoch 26/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9575 - val_loss: -0.7165
#
# Epoch 00026: val_loss did not improve from -0.73741
# Epoch 27/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9577 - val_loss: -0.7155
#
# Epoch 00027: val_loss did not improve from -0.73741
# Epoch 28/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9586 - val_loss: -0.7172
#
# Epoch 00028: val_loss did not improve from -0.73741
# Epoch 29/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9603 - val_loss: -0.7225
#
# Epoch 00029: val_loss did not improve from -0.73741
# Epoch 30/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9626 - val_loss: -0.7132
#
# Epoch 00030: val_loss did not improve from -0.73741
# Epoch 31/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9648 - val_loss: -0.7317
#
# Epoch 00031: val_loss did not improve from -0.73741
# Epoch 32/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9637 - val_loss: -0.7320
#
# Epoch 00032: val_loss did not improve from -0.73741
# Epoch 33/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9644 - val_loss: -0.7160
#
# Epoch 00033: val_loss did not improve from -0.73741
# Epoch 34/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9645 - val_loss: -0.7430
#
# Epoch 00034: val_loss improved from -0.73741 to -0.74301, saving model to model_keras0516GPU0.h5
# Epoch 35/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9651 - val_loss: -0.7320
#
# Epoch 00035: val_loss did not improve from -0.74301
# Epoch 36/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9666 - val_loss: -0.7276
#
# Epoch 00036: val_loss did not improve from -0.74301
# Epoch 37/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9678 - val_loss: -0.7247
#
# Epoch 00037: val_loss did not improve from -0.74301
# Epoch 38/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9680 - val_loss: -0.7268
#
# Epoch 00038: val_loss did not improve from -0.74301
# Epoch 39/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9681 - val_loss: -0.7385
#
# Epoch 00039: val_loss did not improve from -0.74301
# Epoch 40/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9695 - val_loss: -0.7475
#
# Epoch 00040: val_loss improved from -0.74301 to -0.74746, saving model to model_keras0516GPU0.h5
# Epoch 41/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9702 - val_loss: -0.7094
#
# Epoch 00041: val_loss did not improve from -0.74746
# Epoch 42/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9714 - val_loss: -0.7210
#
# Epoch 00042: val_loss did not improve from -0.74746
# Epoch 43/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9714 - val_loss: -0.7158
#
# Epoch 00043: val_loss did not improve from -0.74746
# Epoch 44/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9711 - val_loss: -0.7065
#
# Epoch 00044: val_loss did not improve from -0.74746
# Epoch 45/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9705 - val_loss: -0.7150
#
# Epoch 00045: val_loss did not improve from -0.74746
# Epoch 46/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9711 - val_loss: -0.7294
#
# Epoch 00046: val_loss did not improve from -0.74746
# Epoch 47/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9720 - val_loss: -0.7230
#
# Epoch 00047: val_loss did not improve from -0.74746
# Epoch 48/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9729 - val_loss: -0.7232
#
# Epoch 00048: val_loss did not improve from -0.74746
# Epoch 49/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9729 - val_loss: -0.7454
#
# Epoch 00049: val_loss did not improve from -0.74746
# Epoch 50/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9728 - val_loss: -0.7201
#
# Epoch 00050: val_loss did not improve from -0.74746
# Epoch 51/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9742 - val_loss: -0.7097
#
# Epoch 00051: val_loss did not improve from -0.74746
# Epoch 52/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9747 - val_loss: -0.7115
#
# Epoch 00052: val_loss did not improve from -0.74746
# Epoch 53/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9749 - val_loss: -0.7177
#
# Epoch 00053: val_loss did not improve from -0.74746
# Epoch 54/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9731 - val_loss: -0.7274
#
# Epoch 00054: val_loss did not improve from -0.74746
# Epoch 55/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9742 - val_loss: -0.7238
#
# Epoch 00055: val_loss did not improve from -0.74746
# Epoch 56/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9751 - val_loss: -0.7137
#
# Epoch 00056: val_loss did not improve from -0.74746
# Epoch 57/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9758 - val_loss: -0.7330
#
# Epoch 00057: val_loss did not improve from -0.74746
# Epoch 58/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9761 - val_loss: -0.7214
#
# Epoch 00058: val_loss did not improve from -0.74746
# Epoch 59/200
# 1150/1150 [==============================] - 9s 8ms/step - loss: -0.9743 - val_loss: -0.6572
#
# Epoch 00059: val_loss did not improve from -0.74746
# Epoch 60/200
# 1150/1150 [==============================] - 9s 7ms/step - loss: -0.9742 - val_loss: -0.6992
#
# Epoch 00060: val_loss did not improve from -0.74746

# %% [markdown]
# # conv to last lyr

# %%
img_rows, img_cols = 256, 256
img_channels = 1

batch_size =50
latent_dim = 256
nb_epoch = 50
intermediate_dim =256
original_dim = img_rows*img_cols
LRelu = 'relu'

#USE = 'autoencoder'
#USE = 'vae'
#encoder:

input_img = Input(shape=(img_rows, img_cols,img_channels))
input_flo = Input(shape=(img_rows, img_cols,3))
input_rflo = Input(shape=(img_rows, img_cols,3))

concate_flo = Concatenate()([input_flo,input_rflo])
conv_flo_1 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(concate_flo)
conv_flo_1 = Activation('relu')(conv_flo_1)
conv_flo_1 = BatchNormalization()(conv_flo_1)
#maxpool_flo_1 = MaxPooling2D((2, 2),padding='same')(conv_flo_1)
conv_flo_2 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(conv_flo_1)
conv_flo_2 = Activation('relu')(conv_flo_2)
conv_flo_2 = BatchNormalization()(conv_flo_2)
#maxpool_flo_2 = MaxPooling2D((2, 2),  padding='same')(conv_flo_2)
conv_flo_3 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(conv_flo_2)
conv_flo_3 = Activation(LRelu)(conv_flo_3)
conv_flo_3 = BatchNormalization()(conv_flo_3)






conv_1 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(input_img)
conv_1 = Activation('relu')(conv_1)
conv_1 = BatchNormalization()(conv_1)
maxpool_1 = MaxPooling2D((2, 2),padding='same')(conv_1)
#maxpool_1 = Dropout(0.3)(maxpool_1)

conv_2 = Conv2D(20, (3, 3), padding='same',kernel_initializer='normal',dilation_rate=2)(maxpool_1)
conv_2 = Activation('relu')(conv_2)
#conv_2 = Dropout(0.3)(conv_2)
conv_2 = BatchNormalization()(conv_2)
maxpool_2 = MaxPooling2D((2, 2),  padding='same')(conv_2)
#maxpool_2 = Dropout(0.3)(maxpool_2)

conv_3 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_2)
conv_3 = Activation(LRelu)(conv_3)
#conv_3 = Dropout(0.3)(conv_3)
conv_3 = BatchNormalization()(conv_3)
maxpool_3 = MaxPooling2D((2, 2),  padding='same')(conv_3)
#maxpool_3 = Dropout(0.3)(maxpool_3)

conv_4 = Conv2D(20, (3, 3),padding='same',kernel_initializer='normal',dilation_rate=1)(maxpool_3)
conv_4 = Activation(LRelu)(conv_4)
#conv_4 = Dropout(0.3)(conv_4)
conv_4 = BatchNormalization()(conv_4)
maxpool_4 = MaxPooling2D((2, 2),  padding='same')(conv_4)
#maxpool_4 = Dropout(0.3)(maxpool_4)

#conv_5 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(maxpool_4)
#maxpool_5 = MaxPooling2D((2, 2),  padding='same')(conv_5)


#x = Conv2D(5, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(x)
#x = MaxPooling2D((2, 2),  padding='same')(x)


visual = Flatten()(maxpool_4)
h_1 = Dense(intermediate_dim, activation='relu')(visual)#relu?
encoded = Dense(latent_dim, activation='tanh')(h_1)# relu?


h_3 = Dense(intermediate_dim,activation=LRelu)(encoded)#for AE

h_4 = Dense(20*16*16,activation=LRelu)(h_3)
h_5 = Reshape((16,16,20))(h_4)


#conv_6 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
#upsample_6 = UpSampling2D((2, 2))(conv_6)

conv_7 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(h_5)
upsample_7 = UpSampling2D((2, 2))(conv_7)

upsample_7 = Concatenate()([upsample_7,conv_4])
conv_8 = Conv2D(20, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(upsample_7)
upsample_8 = UpSampling2D((2, 2))(conv_8)

upsample_8 = Concatenate()([upsample_8,conv_3])
conv_9 = Conv2D(10, (3, 3), activation='relu', padding='same',kernel_initializer='normal')(upsample_8)
upsample_9 = UpSampling2D((2, 2))(conv_9)

upsample_9 = Concatenate()([upsample_9,conv_2])
conv_10 = Conv2D(5,  (3, 3), activation='relu',padding='same',kernel_initializer='normal')(upsample_9)
upsample_10 = UpSampling2D((2, 2))(conv_10)

upsample_10 = Concatenate()([upsample_10,conv_1,conv_flo_3])
decoded = Conv2D(2, (3, 3), activation='softmax', padding='same')(upsample_10)
#decoded = Flatten()(decoded)
#decoded = Dense(256*256,activation='softmax')(decoded)


EarlyStopping = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=0, mode='auto')
checkpoint = ModelCheckpoint('model_keras0516GPU0.h5',monitor ='val_loss',verbose = 1,save_best_only = True)

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true[:,:,:,1]) 
    y_pred_f = K.flatten(y_pred[:,:,:,1]) 
    intersection = K.sum(y_true_f * y_pred_f) 
    return (2. * intersection + 1e-6) / (K.sum(K.square(y_true_f)) + K.sum(K.square(y_pred_f)) + 1e-6)
def dice_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

#def ae_loss(x, decoded):  
#    xent_loss = original_dim * objectives.mean_squared_error(x,decoded)
#    return xent_loss
adam = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
autoencoder = Model(inputs=[input_img,input_flo,input_rflo], outputs=decoded)
autoencoder.compile(optimizer=adam, loss=dice_loss)

# %%
#CheckPoint = keras.callbacks.ModelCheckpoint("Model_keras.h5", monitor='val_loss', verbose=0, save_best_only=False, save_weights_only=False, mode='auto', period=1)
autoencoder.fit([train_img[:1150],train_flo[:1150],train_rflo[:1150]], train_seg[:1150],
        shuffle=True,
        epochs=200,
        batch_size=batch_size,
        validation_data=([train_img[1150:],train_flo[1150:],train_rflo[1150:]],train_seg[1150:]),callbacks=[EarlyStopping,checkpoint])
# Out:
# Train on 1150 samples, validate on 127 samples
# Epoch 1/200
# 1150/1150 [==============================] - 17s 15ms/step - loss: -0.1900 - val_loss: -0.0611
#
# Epoch 00001: val_loss improved from inf to -0.06112, saving model to model_keras0516GPU0.h5
# Epoch 2/200
# 1150/1150 [==============================] - 13s 11ms/step - loss: -0.2325 - val_loss: -0.0953
#
# Epoch 00002: val_loss improved from -0.06112 to -0.09535, saving model to model_keras0516GPU0.h5
# Epoch 3/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.3399 - val_loss: -0.3534
#
# Epoch 00003: val_loss improved from -0.09535 to -0.35336, saving model to model_keras0516GPU0.h5
# Epoch 4/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.5473 - val_loss: -0.4289
#
# Epoch 00004: val_loss improved from -0.35336 to -0.42894, saving model to model_keras0516GPU0.h5
# Epoch 5/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.6108 - val_loss: -0.3991
#
# Epoch 00005: val_loss did not improve from -0.42894
# Epoch 6/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.6878 - val_loss: -0.2934
#
# Epoch 00006: val_loss did not improve from -0.42894
# Epoch 7/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.7541 - val_loss: -0.2625
#
# Epoch 00007: val_loss did not improve from -0.42894
# Epoch 8/200
# 1150/1150 [==============================] - 13s 11ms/step - loss: -0.8114 - val_loss: -0.4177
#
# Epoch 00008: val_loss did not improve from -0.42894
# Epoch 9/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.8452 - val_loss: -0.5634
#
# Epoch 00009: val_loss improved from -0.42894 to -0.56343, saving model to model_keras0516GPU0.h5
# Epoch 10/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.8676 - val_loss: -0.6396
#
# Epoch 00010: val_loss improved from -0.56343 to -0.63960, saving model to model_keras0516GPU0.h5
# Epoch 11/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.8827 - val_loss: -0.6331
#
# Epoch 00011: val_loss did not improve from -0.63960
# Epoch 12/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.8930 - val_loss: -0.6668
#
# Epoch 00012: val_loss improved from -0.63960 to -0.66684, saving model to model_keras0516GPU0.h5
# Epoch 13/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9035 - val_loss: -0.6796
#
# Epoch 00013: val_loss improved from -0.66684 to -0.67963, saving model to model_keras0516GPU0.h5
# Epoch 14/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9103 - val_loss: -0.6677
#
# Epoch 00014: val_loss did not improve from -0.67963
# Epoch 15/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9152 - val_loss: -0.6889
#
# Epoch 00015: val_loss improved from -0.67963 to -0.68889, saving model to model_keras0516GPU0.h5
# Epoch 16/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9223 - val_loss: -0.7004
#
# Epoch 00016: val_loss improved from -0.68889 to -0.70035, saving model to model_keras0516GPU0.h5
# Epoch 17/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9254 - val_loss: -0.7099
#
# Epoch 00017: val_loss improved from -0.70035 to -0.70992, saving model to model_keras0516GPU0.h5
# Epoch 18/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9298 - val_loss: -0.7092
#
# Epoch 00018: val_loss did not improve from -0.70992
# Epoch 19/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9333 - val_loss: -0.7174
#
# Epoch 00019: val_loss improved from -0.70992 to -0.71742, saving model to model_keras0516GPU0.h5
# Epoch 20/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9381 - val_loss: -0.7260
#
# Epoch 00020: val_loss improved from -0.71742 to -0.72604, saving model to model_keras0516GPU0.h5
# Epoch 21/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9416 - val_loss: -0.7372
#
# Epoch 00021: val_loss improved from -0.72604 to -0.73717, saving model to model_keras0516GPU0.h5
# Epoch 22/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9439 - val_loss: -0.7273
#
# Epoch 00022: val_loss did not improve from -0.73717
# Epoch 23/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9447 - val_loss: -0.7222
#
# Epoch 00023: val_loss did not improve from -0.73717
# Epoch 24/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9459 - val_loss: -0.7682
#
# Epoch 00024: val_loss improved from -0.73717 to -0.76821, saving model to model_keras0516GPU0.h5
# Epoch 25/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9478 - val_loss: -0.7138
#
# Epoch 00025: val_loss did not improve from -0.76821
# Epoch 26/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9496 - val_loss: -0.7179
#
# Epoch 00026: val_loss did not improve from -0.76821
# Epoch 27/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9513 - val_loss: -0.7504
#
# Epoch 00027: val_loss did not improve from -0.76821
# Epoch 28/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9516 - val_loss: -0.7765
#
# Epoch 00028: val_loss improved from -0.76821 to -0.77648, saving model to model_keras0516GPU0.h5
# Epoch 29/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9548 - val_loss: -0.7618
#
# Epoch 00029: val_loss did not improve from -0.77648
# Epoch 30/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9564 - val_loss: -0.7671
#
# Epoch 00030: val_loss did not improve from -0.77648
# Epoch 31/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9567 - val_loss: -0.7652
#
# Epoch 00031: val_loss did not improve from -0.77648
# Epoch 32/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9583 - val_loss: -0.7173
#
# Epoch 00032: val_loss did not improve from -0.77648
# Epoch 33/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9580 - val_loss: -0.7513
#
# Epoch 00033: val_loss did not improve from -0.77648
# Epoch 34/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9600 - val_loss: -0.7421
#
# Epoch 00034: val_loss did not improve from -0.77648
# Epoch 35/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9620 - val_loss: -0.7522
#
# Epoch 00035: val_loss did not improve from -0.77648
# Epoch 36/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9623 - val_loss: -0.7346
#
# Epoch 00036: val_loss did not improve from -0.77648
# Epoch 37/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9625 - val_loss: -0.7607
#
# Epoch 00037: val_loss did not improve from -0.77648
# Epoch 38/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9605 - val_loss: -0.7491
#
# Epoch 00038: val_loss did not improve from -0.77648
# Epoch 39/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9615 - val_loss: -0.7473
#
# Epoch 00039: val_loss did not improve from -0.77648
# Epoch 40/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9633 - val_loss: -0.7509
#
# Epoch 00040: val_loss did not improve from -0.77648
# Epoch 41/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9660 - val_loss: -0.7597
#
# Epoch 00041: val_loss did not improve from -0.77648
# Epoch 42/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9664 - val_loss: -0.7503
#
# Epoch 00042: val_loss did not improve from -0.77648
# Epoch 43/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9682 - val_loss: -0.7731
#
# Epoch 00043: val_loss did not improve from -0.77648
# Epoch 44/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9686 - val_loss: -0.7451
#
# Epoch 00044: val_loss did not improve from -0.77648
# Epoch 45/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9693 - val_loss: -0.7355
#
# Epoch 00045: val_loss did not improve from -0.77648
# Epoch 46/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9696 - val_loss: -0.7523
#
# Epoch 00046: val_loss did not improve from -0.77648
# Epoch 47/200
# 1150/1150 [==============================] - 12s 11ms/step - loss: -0.9699 - val_loss: -0.7466
#
# Epoch 00047: val_loss did not improve from -0.77648
# Epoch 48/200
# 1150/1150 [==============================] - 12s 10ms/step - loss: -0.9699 - val_loss: -0.7552
#
# Epoch 00048: val_loss did not improve from -0.77648
